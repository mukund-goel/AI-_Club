# %% [markdown]
# # RAVDESS Phase 2: Model Training
# ## 1. Setup & Imports

# %%
import os
import sys
import tensorflow as tf

# Add paths
sys.path.append(os.path.abspath(os.path.join('..', 'modeling')))
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

from cnn_model import create_cnn_model
from dataset import load_data, split_data, EMOTIONS
from train import train

# %% [markdown]
# ## 2. Model Architecture

# %%
model = create_cnn_model(input_shape=(128, 300, 1), num_classes=8)
model.summary()

# %% [markdown]
# ## 3. Training Loop
# Executing the training script. This saves `best_model.h5`.

# %%
# Run training (takes time)
# We can call the train function directly
try:
    train()
except Exception as e:
    print(f"Training error: {e}")
